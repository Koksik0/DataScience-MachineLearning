# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# !pip install seaborn

# %%
# !pip install statsmodels

# %% [markdown]
# ## Exercise 1
# a) Load house sales data from file kc_house_data.csv, print first records.
# b) Print the variable list. Select categorical and numerical variables.
# c) Compute basic statistics of numerical variables. Are all of them meaningful?

# %%
#a)
#Your code:
df = pd.read_csv('kc_house_data.csv')
df.head()

#Hint: read_csv(), head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %%
#b) 
print('Columns:')
print(df.columns)
print()
print('Categorical variable: ')
house_categorical_df = [
    'date','waterfront','view','condition','grade','zipcode'
]
print(house_categorical_df)
print("Numerical variable: ")
house_numerical_df = [
    'id','price','bedrooms','bathrooms','sqft_living','sqft_lot','floors','sqft_above','sqdt_basement','yr_built',
    'yr_renovated','lat','long','sqft_living15','sqft_lot15'
]
print(house_numerical_df)
# Out:
# Columns:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')
#
# Categorical variable:
# ['date', 'waterfront', 'view', 'condition', 'grade', 'zipcode']
# Numerical variable:
# ['id', 'price', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot', 'floors', 'sqft_above', 'sqdt_basement', 'yr_built', 'yr_renovated', 'lat', 'long', 'sqft_living15', 'sqft_lot15']

# %%
#c)
#Your code:

df.describe()

#Hint: Function describe()
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.161300e+04  2.161300e+04  21613.000000  21613.000000  21613.000000
# mean   4.580302e+09  5.400881e+05      3.370842      2.114757   2079.899736
# std    2.876566e+09  3.671272e+05      0.930062      0.770163    918.440897
# min    1.000102e+06  7.500000e+04      0.000000      0.000000    290.000000
# 25%    2.123049e+09  3.219500e+05      3.000000      1.750000   1427.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    waterfront          view     condition  \
# count  2.161300e+04  21613.000000  21613.000000  21613.000000  21613.000000
# mean   1.510697e+04      1.494309      0.007542      0.234303      3.409430
# ...

# %% [raw]
# Count in this case is the number of not-empty values. This may be useful when we want to check whether the data is complete but it is useless when it comes to statistic.
#
# Mean is a measure of central tendency.
# The standard deviation describes the dispersion of the data around the mean.
# The smallest value in the column.
# First quartile is the value below which 25% of the data falls.
# The median is a value that divides the data into two equal parts.
# The third quartile is Value, below which 75% of the data is.
# The largest value in the column.
#
# The average price is around 540,000, but the std of the price is around 367,000. This means there are large differences between housing prices, which may be influenced by various other factors included in this dataset.
# As we can see the median is 450000 and this mean that the majority of prices is below the mean.
#
# House prices are influenced by various factors included in this dataset. To my mind, the most important factors influencing the price are: square footage, condition and grade. The average area is 2079 and the median is 1427, so it behaves like price. The same observation can be seen in the column condition and grade.

# %% [markdown]
# ## Exercise 2
# Using scatter plot:
# a) Show the relation of square footage and price.
# b) Check how price is influenced by apartment's grade. Find other variables correlated with price.
# c) Check how good apartments are distributed over the city. First, plot zipcode versus price. Then, use apartments coordinates (longitude and lattitude) in order to show where apartments of good grade are located.

# %%
#a)
#Your code:
plt.scatter(df['sqft_living'],df['price'])
plt.xlabel('Square footage')
plt.ylabel('Price')
plt.show()
#Hint plt.scatter

# %% [markdown]
# Most of data is in a group. We see that the area is very important depending on the price. There are several outliers but one of them does not follow the trend we see. Below we can see three apartments with the largest area. The biggest one is the outlier. To my mind this house has a low price because it has never been renovated and its neighbors have huge plots of land.

# %%
a = df[df['sqft_living'] > 10000]
a
# Out:
#                id             date      price  bedrooms  bathrooms  \
# 3914   9808700762  20140611T000000  7062500.0         5        4.5
# 7252   6762700020  20141013T000000  7700000.0         6        8.0
# 12777  1225069038  20140505T000000  2280000.0         7        8.0
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 3914         10040     37325     2.0           1     2  ...     11
# 7252         12050     27600     2.5           0     3  ...     13
# 12777        13540    307752     3.0           0     4  ...     12
#
#        sqft_above  sqft_basement  yr_built  yr_renovated  zipcode      lat  \
# 3914         7680           2360      1940          2001    98004  47.6500
# 7252         8570           3480      1910          1987    98102  47.6298
# 12777        9410           4130      1999             0    98053  47.6675
#
#           long  sqft_living15  sqft_lot15
# 3914  -122.214           3930       25449
# ...

# %%
#b)
#Your code:
plt.scatter(df['grade'],df['price'])
plt.xlabel('Grade')
plt.ylabel('Price')
plt.show()

# %% [markdown]
# As we can see in the chart above, the tendency is that the higher the rating, the higher the price. However, for a rating of 13, we see large discrepancies between the prices of individual apartments.

# %%
b = df[df['grade']==13]
b
# Out:
#                id             date      price  bedrooms  bathrooms  \
# 4411   2470100110  20140804T000000  5570000.0         5       5.75
# 4811   9831200500  20150304T000000  2479000.0         5       3.75
# 5451   7237501190  20141010T000000  1780000.0         4       3.25
# 6041   1725059316  20141120T000000  2385000.0         4       4.00
# 7035    853200010  20140701T000000  3800000.0         5       5.50
# 7252   6762700020  20141013T000000  7700000.0         6       8.00
# 7907   1068000375  20140923T000000  3200000.0         6       5.00
# 9254   9208900037  20140919T000000  6885000.0         6       7.75
# 10373  3303850390  20141212T000000  2983000.0         5       5.50
# 13411  2426039123  20150130T000000  2415000.0         5       4.75
# 13700  4139900180  20150420T000000  2340000.0         4       2.50
# 14556  2303900035  20140611T000000  2888000.0         5       6.25
# 19017  2303900100  20140911T000000  3800000.0         3       4.25
#
# ...

# %%
#c)
#Your code:
plt.scatter(df['zipcode'],df['price'])
plt.xlabel('Zipcode')
plt.ylabel('Price')
plt.show()

# %% [markdown]
# In this chart, we can see larger clusters of data, which means that there is a larger selection of apartments in a given area and we should look for an apartment there because there is a greater probability of purchasing the apartment of our dreams.

# %%
#Your code:
plt.scatter(df['long'], df['lat'], c=df['grade'], cmap='viridis')
plt.xlabel('Longitude')
plt.ylabel('Lattitude')
plt.colorbar(label = 'Grade')
plt.show()

# %% [markdown]
# In the chart above we see apartments depending on geographical location. We also see color measures that indicate the rating of a given apartment. On the upper left side we can definitely see that it has the most apartments with the highest ratings.

# %% [markdown]
# ## Exercise 3
# a) Create boxplot of apartment's grade versus it's price. Compare with plot 2b).
# b) Create mosaic plot of any two categorical variables.

# %%
#a)
#Your code:
import seaborn as sns
data = df[['grade','price']]
sns.boxplot(x = 'grade', y = 'price', data = data)
plt.show()
#Hint: plt.boxplot

# %% [markdown]
# We are able to read much more information on the boxplot chart. This is important because in the chart above we see the median and percentiles, while in chart 2b we could incorrectly estimate the median, especially for the middle grade values, because in chart 2b the data on apartments merge and it is not clear whether there are several apartments in a given place or several hundred

# %%
#b)
from statsmodels.graphics.mosaicplot import mosaic

#Your code:
mosaic(df,index = ['bedrooms','grade'])
plt.show()

# %% [markdown]
# This mosaic plot illustrates the relationship between the number of bedrooms and the quality of properties. It shows how different combinations of bedroom counts and quality levels are distributed in the dataset. The plot helps identify patterns and potential associations between these variables.

# %% [markdown]
# ## Exercise 4
# "I am interested in the house with 3 bedrooms, 2 bathrooms and 2 floors"
# a) Compute the basic statistics of apartments fulfilling above constraints.
# b) Distinct accepted apartments on any of previously created plots.
# c) Find such apartments with best price to footage ratio.

# %%
#a)
#Your code:
ex4 = df.loc[(df['bedrooms']==3) & (df['bathrooms']==2) & (df['floors']==2)]
ex4.describe()
#Hint: pandas.DataFrame.loc
# Out:
#                  id         price  bedrooms  bathrooms  sqft_living  \
# count  1.540000e+02  1.540000e+02     154.0      154.0   154.000000
# mean   4.397177e+09  5.144986e+05       3.0        2.0  1850.279221
# std    2.849813e+09  2.497661e+05       0.0        0.0   547.585413
# min    7.600057e+06  2.090000e+05       3.0        2.0  1020.000000
# 25%    2.060901e+09  3.769750e+05       3.0        2.0  1452.500000
# 50%    3.630010e+09  4.640000e+05       3.0        2.0  1700.000000
# 75%    7.184074e+09  5.894625e+05       3.0        2.0  2127.500000
# max    9.829200e+09  1.755000e+06       3.0        2.0  3650.000000
#
#             sqft_lot  floors  waterfront        view   condition       grade  \
# count     154.000000   154.0  154.000000  154.000000  154.000000  154.000000
# mean    23678.948052     2.0    0.006494    0.357143    3.435065    7.551948
# std     83324.024708     0.0    0.080582    0.919495    0.713322    0.832684
# ...

# %% [markdown]
# In this example, all the houses in question have the same 3 features and we can see that the std for the apartment rating is small, which may indicate that these 3 common features have a large impact on the rating. When it comes to price, its median is lower than the average, which means that there are more cheaper apartments in this data set. In the view column we have a very low average but a much higher std, which means that the vast majority of these apartments have a very poor score, but there are a few apartments with the highest score.

# %%
#b)
#Your code:
plt.scatter(df['grade'],df['price'])
plt.scatter(ex4['grade'],ex4['price'],color = 'r')
plt.xlabel('Grade')
plt.ylabel('Price')
plt.show()

# %% [markdown]
# I selected data from task 2b and displayed it against the entire dataset. As you can see, all these apartments have a rating from 6 to 10, which confirms the small std from point a.

# %%
#c)
#Your code:
df['price/sqft_living'] = df['price']/df['sqft_living']
df.sort_values(by='price/sqft_living',ascending=True,inplace = True)
ex4 = df.loc[(df['bedrooms']==3) & (df['bathrooms']==2) & (df['floors']==2)]
ex4.head()
#Hint: .loc, .sort_values(), .index
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 9704   7452500565  20140829T000000  260000.0         3        2.0
# 11258  7937600262  20140710T000000  379900.0         3        2.0
# 19880  3832050860  20150319T000000  210000.0         3        2.0
# 16014  5104450440  20141113T000000  252500.0         3        2.0
# 20906  3355400242  20141028T000000  274900.0         3        2.0
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  sqft_above  \
# 9704          2710      5000     2.0           0     0  ...        2710
# 11258         3110     44967     2.0           0     0  ...        3020
# 19880         1580      4961     2.0           0     0  ...        1580
# 16014         1810     10684     2.0           0     0  ...        1810
# 20906         1936      6612     2.0           0     0  ...        1936
#
#        sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# ...
